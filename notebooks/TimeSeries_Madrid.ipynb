# %% [markdown]
# # **Time Series**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels

# %%
df = pd.read_csv('../data/processed/Madrid_pollutants.csv')
clean_df = pd.read_csv('../data/processed/clean_madrid.csv')

# %%
clean_df.shape
# Out:
# (53931, 8)

# %%
df.shape
# Out:
# (53931, 34)

# %%
# Supongamos que tienes un DataFrame df1 y has eliminado una columna llamada 'columna_eliminada' Puedes recuperar la columna eliminada de df1 de la siguiente manera
columna_recuperada = df['FECHA']

# Luego, supongamos que tienes otro DataFrame df2 al que deseas agregar la columna recuperada
# Puedes agregarla usando la función concat de pandas
clean_df['FECHA'] = columna_recuperada

# Ahora, df2 contiene la columna recuperada de df1 como 'columna_nueva'

# %%
clean_df.head()
# Out:
#   N_MUNICIPIO MAGNITUD TIPO_AREA TIPO_ESTACION   LATITUD  LONGITUD  \
# 0  ALCOBENDAS     C6H6    URBANA       TRAFICO  40.54035  -3.64525
# 1  ALCOBENDAS     C6H6    URBANA       TRAFICO  40.54035  -3.64525
# 2  ALCOBENDAS     C6H6    URBANA       TRAFICO  40.54035  -3.64525
# 3  ALCOBENDAS     C6H6    URBANA       TRAFICO  40.54035  -3.64525
# 4  ALCOBENDAS     C6H6    URBANA       TRAFICO  40.54035  -3.64525
#
#    MEDIA_DIARIA PELIGROSIDAD       FECHA
# 0      1.045833          Low  2022-01-01
# 1      0.966667          Low  2022-01-02
# 2      1.175000          Low  2022-01-03
# 3      1.087500          Low  2022-01-04
# 4      0.429167          Low  2022-01-05

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Supongamos que tienes un DataFrame llamado 'clean_df' con columnas 'FECHA', 'MAGNITUD', 'MEDIA_DIARIA' y 'PELIGROSIDAD'

# Configuración de estilo de seaborn
sns.set_style("whitegrid")

# Crear un gráfico de líneas con diferentes colores para cada nivel de peligrosidad
plt.figure(figsize=(12, 6))
sns.lineplot(data=clean_df, x='FECHA', y='MEDIA_DIARIA', hue='PELIGROSIDAD', palette='viridis')

# Añadir etiquetas y título
plt.xlabel("Fecha")
plt.ylabel("Nivel de Contaminante")
plt.title("Evolución de Contaminantes por Nivel de Peligrosidad a lo largo del Tiempo")

# Rotar etiquetas del eje x para una mejor legibilidad
plt.xticks(rotation=45)

# Mostrar la leyenda
plt.legend(title='Nivel de Peligrosidad')

# Mostrar el gráfico
plt.show()

# %%
import pandas as pd

# Supongamos que 'clean_df' es tu DataFrame con una columna 'FECHA' en formato 'str'
clean_df['FECHA'] = pd.to_datetime(clean_df['FECHA'])

# Luego, puedes realizar la comparación de fechas
fecha_inicio = pd.to_datetime('2022-01-01')
fecha_fin = pd.to_datetime('2022-05-30')

datos_rango_fechas = clean_df[(clean_df['FECHA'] >= fecha_inicio) & (clean_df['FECHA'] <= fecha_fin)]
print(datos_rango_fechas)
# Out:
#         N_MUNICIPIO MAGNITUD  TIPO_AREA TIPO_ESTACION   LATITUD  LONGITUD  \
# 0      <<<<<<< HEAD      NaN        NaN           NaN       NaN       NaN
# 1        ALCOBENDAS     C6H6     URBANA       TRAFICO  40.54035  -3.64525
# 2        ALCOBENDAS     C6H6     URBANA       TRAFICO  40.54035  -3.64525
# 3        ALCOBENDAS     C6H6     URBANA       TRAFICO  40.54035  -3.64525
# 4        ALCOBENDAS     C6H6     URBANA       TRAFICO  40.54035  -3.64525
# ...             ...      ...        ...           ...       ...       ...
# 53750      MÓSTOLES      SO2  SUBURBANA         FONDO  40.32420  -3.87677
# 53751      MÓSTOLES      SO2  SUBURBANA         FONDO  40.32420  -3.87677
# 53752      MÓSTOLES      SO2  SUBURBANA         FONDO  40.32420  -3.87677
# 53753      MÓSTOLES      SO2  SUBURBANA         FONDO  40.32420  -3.87677
# 53754      MÓSTOLES      SO2  SUBURBANA         FONDO  40.32420  -3.87677
#
#        MEDIA_DIARIA PELIGROSIDAD      FECHA
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Supongamos que tienes un DataFrame llamado 'datos_rango_fechas' con columnas 'FECHA', 'MEDIA_DIARIA' y 'PELIGROSIDAD'

# Configuración de estilo de seaborn
sns.set_style("whitegrid")

# Crear un gráfico de líneas para la media de contaminantes por nivel de peligrosidad
plt.figure(figsize=(12, 6))
sns.lineplot(data=datos_rango_fechas, x='FECHA', y='MEDIA_DIARIA', hue='PELIGROSIDAD', palette='viridis')

# Añadir etiquetas y título
plt.xlabel("Fecha")
plt.ylabel("Media de Contaminantes")
plt.title("Evolución de la Media de Contaminantes por Nivel de Peligrosidad")

# Rotar etiquetas del eje x para una mejor legibilidad
plt.xticks(rotation=45)

# Mostrar la leyenda
plt.legend(title='Nivel de Peligrosidad')

# Mostrar el gráfico
plt.show()

# %%
# Luego, puedes realizar la comparación de fechas
fecha_inicio = pd.to_datetime('2022-06-01')
fecha_fin = pd.to_datetime('2022-12-31')

datos_rango_fechas = clean_df[(clean_df['FECHA'] >= fecha_inicio) & (clean_df['FECHA'] <= fecha_fin)]
print(datos_rango_fechas)
# Out:
#       N_MUNICIPIO MAGNITUD  TIPO_AREA TIPO_ESTACION   LATITUD  LONGITUD  \
# 138    ALCOBENDAS     C6H6     URBANA       TRAFICO  40.54035  -3.64525
# 139    ALCOBENDAS     C6H6     URBANA       TRAFICO  40.54035  -3.64525
# 140    ALCOBENDAS     C6H6     URBANA       TRAFICO  40.54035  -3.64525
# 141    ALCOBENDAS     C6H6     URBANA       TRAFICO  40.54035  -3.64525
# 142    ALCOBENDAS     C6H6     URBANA       TRAFICO  40.54035  -3.64525
# ...           ...      ...        ...           ...       ...       ...
# 53926    MÓSTOLES      SO2  SUBURBANA         FONDO  40.32420  -3.87677
# 53927    MÓSTOLES      SO2  SUBURBANA         FONDO  40.32420  -3.87677
# 53928    MÓSTOLES      SO2  SUBURBANA         FONDO  40.32420  -3.87677
# 53929    MÓSTOLES      SO2  SUBURBANA         FONDO  40.32420  -3.87677
# 53930    MÓSTOLES      SO2  SUBURBANA         FONDO  40.32420  -3.87677
#
#        MEDIA_DIARIA PELIGROSIDAD      FECHA
# 138        0.191667          Low 2022-06-01
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# Crear un gráfico de líneas para la media de contaminantes por nivel de peligrosidad
plt.figure(figsize=(12, 6))
sns.lineplot(data=datos_rango_fechas, x='FECHA', y='MEDIA_DIARIA', hue='PELIGROSIDAD', palette='viridis')

plt.xlabel("Fecha")
plt.ylabel("Media de Contaminantes")
plt.title("Evolución de la Media de Contaminantes por Nivel de Peligrosidad")

plt.xticks(rotation=45)

plt.legend(title='Nivel de Peligrosidad')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Supongamos que tienes un DataFrame llamado 'clean_df' con columnas 'FECHA', 'MAGNITUD' y 'MEDIA_DIARIA'

# Configuración de estilo de seaborn
sns.set_style("whitegrid")

# Crear un gráfico de líneas para un contaminante específico (por ejemplo, C6H6)
contaminante = 'C6H6'
plt.figure(figsize=(12, 6))
sns.lineplot(data=clean_df[clean_df['MAGNITUD'] == contaminante], x='FECHA', y='MEDIA_DIARIA')

# Añadir etiquetas y título
plt.xlabel("Fecha")
plt.ylabel("Nivel de Contaminante")
plt.title(f"Evolución del Contaminante {contaminante} a lo largo del Tiempo")

# Rotar etiquetas del eje x para una mejor legibilidad
plt.xticks(rotation=45)

# Mostrar el gráfico
plt.show()

# %%
clean_df['FECHA']= pd.to_datetime(clean_df.FECHA)
clean_df = clean_df.set_index('FECHA')
ts_df = clean_df['MEDIA_DIARIA']
ts_df.head()
# Out:
# FECHA
# 2022-01-01         NaN
# 2022-01-02    1.045833
# 2022-01-03    0.966667
# 2022-01-04    1.175000
# 2022-01-05    1.087500
# Name: MEDIA_DIARIA, dtype: float64

# %%
ts_df.info
# Out:
# <bound method Series.info of FECHA
# 2022-01-01         NaN
# 2022-01-02    1.045833
# 2022-01-03    0.966667
# 2022-01-04    1.175000
# 2022-01-05    1.087500
#                 ...
# NaT           2.250000
# NaT           2.791667
# NaT           2.875000
# NaT           3.000000
# NaT           2.958333
# Name: MEDIA_DIARIA, Length: 54599, dtype: float64>

# %% [markdown]
# **Values pollutants history graph**

# %%
ts_df = ts_df.dropna()

# %%
# fig, axis = plt.subplots(figsize = (10, 5))

# sns.lineplot(data = ts_df)

# plt.tight_layout()
# plt.show()

# %% [markdown]
# ### Comentario para explicar la grafica de arriba

# %% [markdown]
# ### **Analysis Time Series**

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

decomposition = seasonal_decompose(ts_df, period = 5)
decomposition

# %% [markdown]
# **Trend graph**

# %%
# trend = decomposition.trend

# fig, axis = plt.subplots(figsize = (10, 5))

# sns.lineplot(data = ts_df)
# sns.lineplot(data = trend)

# plt.tight_layout()

# plt.show()

# %% [markdown]
# **Seasonal graph**

# %%
# seasonal = decomposition.seasonal

# fig, axis = plt.subplots(figsize = (10, 5))

# sns.lineplot(data = ts_df)
# sns.lineplot(data = seasonal)

# plt.tight_layout()

# plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

def test_stationarity(timeseries):
    print('Dickey-Fuller test results:')
    dftest = adfuller(timeseries, autolag = 'AIC')
    dfoutput = pd.Series(dftest[0:4], index = ['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    return dfoutput

test_stationarity(ts_df)
# Out:
# Dickey-Fuller test results:
# Test Statistic                    -4.675536
# p-value                            0.000094
# #Lags Used                        58.000000
# Number of Observations Used    54537.000000
# Critical Value (1%)               -3.430470
# Critical Value (5%)               -2.861593
# Critical Value (10%)              -2.566798
# dtype: float64

# %% [markdown]
# **Es estacionaria**

# %% [markdown]
# ### **Variability analysis**

# %%
# residual = decomposition.resid

# fig, axis = plt.subplots(figsize = (10, 5))

# sns.lineplot(data = ts_df)
# sns.lineplot(data = residual)

# plt.tight_layout()

# plt.show()

# %% [markdown]
# ### **Autocorrelation analysis**

# %%
# from statsmodels.graphics.tsaplots import plot_acf

# plot_acf(ts_df)

# plt.tight_layout()

# plt.show()

# %% [markdown]
# *Ya es estacionaria, no hace falta hacer transformacion para tratarlo como tal*

# %%
from pmdarima import auto_arima

# Supongamos que tienes una serie de tiempo en 'ts_df'

# Realiza la búsqueda automática de hiperparámetros
model = auto_arima(ts_df, seasonal=True, trace=True,
                   start_p=0, max_p=3,
                   start_q=0, max_q=3,
                   start_P=0, max_P=2,
                   start_Q=0, max_Q=2,
                   d=1, D=1, m=12,  # Aquí, 'm' representa la periodicidad estacional (por ejemplo, 12 para datos mensuales)
                   stepwise=True)

# Obtiene los hiperparámetros recomendados
p, d, q = model.order
P, D, Q, s = model.seasonal_order

print(f"Mejores hiperparámetros encontrados:")
print(f"Orden ARIMA: ({p}, {d}, {q})")
print(f"Orden Estacional: ({P}, {D}, {Q}, {s})")
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=504496.650, Time=1.04 sec
# El kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior.
#
# Revise el código de las celdas para identificar una posible causa del error.
#
# Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información.
#
# Vea Jupyter <a href='command:jupyter.viewOutput'>log</a> para obtener más detalles.

# %%
# from statsmodels.tsa.arima.model import ARIMA

# # Ajustar el modelo ARIMA con los hiperparámetros seleccionados
# model = ARIMA(ts_df, order=(p, d, q), seasonal_order=(P, D, Q, s))
# result = model.fit()

# # Resumen del modelo ajustado
# print(result.summary())

# %%
# from pmdarima import auto_arima

# model = auto_arima(ts_df, seasonal=True, trace=True, m=5,
#                    start_p=0, max_p=3,
#                    start_q=0, max_q=3,
#                    start_P=0, max_P=2,
#                    start_Q=0, max_Q=2,
#                    d=1, D=1,
#                    stepwise=True,
#                    maxiter=10)  # Limitar el número de iteraciones
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,1,0)[5]             : AIC=506245.062, Time=0.62 sec
#  ARIMA(1,1,0)(1,1,0)[5]             : AIC=483240.074, Time=6.08 sec
#  ARIMA(0,1,1)(0,1,1)[5]             : AIC=inf, Time=8.26 sec
#  ARIMA(1,1,0)(0,1,0)[5]             : AIC=499804.635, Time=0.67 sec
# El kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior.
#
# Revise el código de las celdas para identificar una posible causa del error.
#
# Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información.
#
# Vea Jupyter <a href='command:jupyter.viewOutput'>log</a> para obtener más detalles.

# %%
# from pickle import dump

# # Save the model to a file named "arima.pk"
# dump(model, open('../models/arima.pk', 'wb'))

# %%
# model.summary()

# %%
# forecast = model.predict(20)
# forecast

# %%
# fig, axis = plt.subplots(figsize = (10, 5))

# sns.lineplot(data = ts_df)
# sns.lineplot(data = forecast, c = "green")

# plt.tight_layout()

# plt.show()
